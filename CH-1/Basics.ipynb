# %% [markdown]
# # **LLM CALL**

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
chat_completion = client.chat.completions.create(
    model="gpt-5-mini",
    messages=[{"role": "user", "content": "Hello, tell me a funfact"}]
)

print(chat_completion.choices[0].message.content)
# Out:
# Fun fact: Botanically, bananas are berries — but strawberries aren’t.
#
# Why: A berry develops from a single ovary and usually has multiple seeds embedded in the flesh (bananas fit). Strawberries are “aggregate accessory fruits”: the tiny dots on the outside are the actual fruits (each with a seed), and the red part is swollen tissue that isn’t from the ovary.
#
# Want another fun fact?

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini",temperature=0)

llm.invoke("Hello, tell me a funfact").content
# Out:
# 'Fun fact: Botanically, bananas are berries but strawberries aren’t. In botanical terms, a berry develops from a single ovary and has fleshy tissue with seeds (think banana, tomato, kiwi), while strawberries, raspberries and blackberries are aggregate fruits formed from many ovaries. Want another?'

# %%
from langchain.chat_models import init_chat_model

chat_model = init_chat_model(model="gpt-5-mini",temperature=0)

chat_model.invoke("Hello, tell me a funfact")
# Out:
# AIMessage(content='Fun fact: wombats produce cube-shaped poop.\n\nWhy: their intestines compress the feces into little cubes so it doesn’t roll away — useful for marking territory on rocks and logs. Want another fun fact (animals, space, history, etc.)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 253, 'prompt_tokens': 13, 'total_tokens': 266, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DG06ePYC8Z8ZBPfvrJknQivbgtGIQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cbd83-5658-7473-aaeb-f7cd064a7179-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 253, 'total_tokens': 266, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})
